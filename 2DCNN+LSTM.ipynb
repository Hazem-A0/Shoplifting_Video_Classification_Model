1.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_9.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_9_1.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_90.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_90_1.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_91.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_91_1.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_92.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_92_1.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_93.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_93_1.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_94.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_94_1.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_95.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_95_1.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_96.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_96_1.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_97.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_97_1.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_98.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_98_1.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_99.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/shop_lifter_n_99_1.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videossssstttsss_48.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videossssstttsss_49.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videossssstttsss_50.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videossssstttsss_51.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videossssstttsss_52.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videossssstttsss_53.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videossssstttsss_54.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videossssstttsss_55.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videossssstttsss_56.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videppppsss_0.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videppppsss_1.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videppppsss_10.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videppppsss_11.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videppppsss_12.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videppppsss_13.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videppppsss_14.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videppppsss_15.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videppppsss_16.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videppppsss_17.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videppppsss_18.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videppppsss_19.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videppppsss_2.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videppppsss_20.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videppppsss_21.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videppppsss_22.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videppppsss_23.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/non shop lifters/videppppsss_24.mp4
# ...
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_27.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_28.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_29.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_3.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_30.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_31.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_32.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_33.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_34.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_35.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_36.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_37.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_38.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_39.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_4.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_40.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_41.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_42.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_43.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_44.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_45.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_46.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_47.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_48.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_49.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_5.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_50.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_51.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_52.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_53.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_54.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_55.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_6.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_7.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_8.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videppppsss_9.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_0.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_1.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_10.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_11.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_12.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_13.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_14.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_15.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_16.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_17.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_18.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_19.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_2.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_20.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_21.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_22.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_23.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_24.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_25.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_26.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_27.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_28.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_29.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_3.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_4.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_5.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_6.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_7.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_8.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyynnnnnnzzzzzyyyss_9.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_0.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_1.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_10.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_11.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_12.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_13.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_14.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_15.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_16.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_17.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_18.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_19.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_2.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_20.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_21.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_22.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_23.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_24.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_25.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_26.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_27.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_28.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_29.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_3.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_30.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_31.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_32.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_33.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_34.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_35.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_36.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_37.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_38.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_39.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_4.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_40.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_41.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_42.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_43.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_44.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_45.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_46.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_47.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_48.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_49.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_5.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_50.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_51.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_52.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_53.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_54.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_55.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_56.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_57.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_58.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_59.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_6.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_60.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_61.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_62.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_63.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_64.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_65.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_7.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_8.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyyyyss_9.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_0.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_1.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_10.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_11.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_12.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_13.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_14.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_15.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_16.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_17.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_18.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_19.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_2.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_20.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_21.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_22.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_23.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_24.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_3.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_4.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_5.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_6.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_7.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_8.mp4
#   inflating: /content/drive/MyDrive/Shop_DataSet/Shop DataSet/shop lifters/videyyyyyyzzzzzyyyss_9.mp4

# %%
import cv2
import numpy as np
import os
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import Sequence
import multiprocessing
from functools import partial

def extract_frames(video_path, target_frames=10, target_size=(112, 112)):
    """Extract a fixed number of frames from a video, with reduced resolution."""
    frames = []
    video = cv2.VideoCapture(video_path)
    total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

    if total_frames == 0:
        return None

    step = max(total_frames // target_frames, 1)
    frame_indices = range(0, min(total_frames, target_frames * step), step)

    for i in frame_indices:
        video.set(cv2.CAP_PROP_POS_FRAMES, i)
        ret, frame = video.read()
        if ret:
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frame = cv2.resize(frame, target_size)
            frames.append(frame)

    video.release()

    # Pad or truncate to ensure we have exactly target_frames
    if len(frames) < target_frames:
        last_frame = frames[-1]
        frames.extend([last_frame] * (target_frames - len(frames)))
    elif len(frames) > target_frames:
        frames = frames[:target_frames]

    return np.array(frames)

def process_video(video_path, label, target_frames=10, target_size=(112, 112)):
    """Process a single video and return frames and label."""
    frames = extract_frames(video_path, target_frames, target_size)
    return frames, label

def load_video_paths(data_dir):
    """Load video paths and labels from the directory structure."""
    video_paths = []
    labels = []
    for label in ['shop_lifters', 'non_shop_lifters']:
        label_dir = os.path.join(data_dir, label)
        if not os.path.isdir(label_dir):
            print(f"Warning: {label_dir} not found.")
            continue
        for video_file in os.listdir(label_dir):
            if video_file.endswith(('.mp4', '.avi', '.mov')):
                video_paths.append(os.path.join(label_dir, video_file))
                labels.append(label)
    return video_paths, labels

class VideoDataGenerator(Sequence):
    def __init__(self, video_paths, labels, batch_size=32, target_frames=10, target_size=(112, 112)):
        self.video_paths = video_paths
        self.labels = labels
        self.batch_size = batch_size
        self.target_frames = target_frames
        self.target_size = target_size
        self.label_encoder = LabelEncoder()
        self.encoded_labels = self.label_encoder.fit_transform(self.labels)

    def __len__(self):
        return int(np.ceil(len(self.video_paths) / float(self.batch_size)))
    def __getitem__(self, idx):
        batch_paths = self.video_paths[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_labels = self.encoded_labels[idx * self.batch_size:(idx + 1) * self.batch_size]

        # Create a list of tuples (video_path, label) for the batch
        batch_data = list(zip(batch_paths, [self.labels[i] for i in batch_labels]))

        with multiprocessing.Pool() as pool:
            # Use pool.starmap to unpack the tuples and provide both arguments to process_video
            results = pool.starmap(partial(process_video,
                                          target_frames=self.target_frames,
                                          target_size=self.target_size),
                                  batch_data)

        batch_frames, _ = zip(*results)
        batch_frames = np.array(batch_frames).astype('float32') / 255.0
        batch_labels = to_categorical(batch_labels)

        return batch_frames, batch_labels

# Example usage:
data_dir = '/content/drive/MyDrive/Shop_DataSet/Shop_DataSet'  # Should contain 'fall' and 'no_fall' subfolders
video_paths, labels = load_video_paths(data_dir)

# Create train and validation generators
from sklearn.model_selection import train_test_split

train_paths, val_paths, train_labels, val_labels = train_test_split(video_paths, labels, test_size=0.2, random_state=42)

train_generator = VideoDataGenerator(train_paths, train_labels)
val_generator = VideoDataGenerator(val_paths, val_labels)

print("Number of training samples:", len(train_paths))
print("Number of validation samples:", len(val_paths))

# Now you can use these generators with your model
# model.fit(train_generator, validation_data=val_generator, epochs=50, ...)
# Out:
# Number of training samples: 684
# Number of validation samples: 171

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, LSTM, Dense, Dropout, Flatten, TimeDistributed
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint



def create_model(input_shape, num_classes):
    model = Sequential([
        TimeDistributed(Conv2D(32, (3, 3), activation='relu'), input_shape=input_shape),
        TimeDistributed(MaxPooling2D((2, 2))),
        TimeDistributed(Conv2D(64, (3, 3), activation='relu')),
        TimeDistributed(MaxPooling2D((2, 2))),
        TimeDistributed(Conv2D(64, (3, 3), activation='relu')),
        TimeDistributed(MaxPooling2D((2, 2))),
        TimeDistributed(Flatten()),
        LSTM(100, return_sequences=True),
        LSTM(100),
        Dense(64, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    return model

# Set up model parameters
input_shape = (10, 112, 112, 3)  # (frames, height, width, channels)
num_classes = 2  # fall and no_fall

# Create the model
model = create_model(input_shape, num_classes)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
#model_checkpoint = ModelCheckpoint('best_model.keras', save_best_only=True, monitor='val_accuracy') # Change .h5 to .keras

# Train the model
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=50,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 532s 18s/step - accuracy: 0.5507 - loss: 0.6922 - val_accuracy: 0.6082 - val_loss: 0.6702
# Epoch 2/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 472s 16s/step - accuracy: 0.6356 - loss: 0.6655 - val_accuracy: 0.6082 - val_loss: 0.6688
# Epoch 3/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 468s 16s/step - accuracy: 0.6335 - loss: 0.6649 - val_accuracy: 0.6082 - val_loss: 0.6718
# Epoch 4/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 469s 16s/step - accuracy: 0.6375 - loss: 0.6619 - val_accuracy: 0.6082 - val_loss: 0.6710
# Epoch 5/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 515s 18s/step - accuracy: 0.6499 - loss: 0.6634 - val_accuracy: 0.6082 - val_loss: 0.6653
# Epoch 6/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 507s 16s/step - accuracy: 0.6549 - loss: 0.6421 - val_accuracy: 0.6082 - val_loss: 0.7182
# Epoch 7/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 458s 16s/step - accuracy: 0.7546 - loss: 0.5690 - val_accuracy: 0.8421 - val_loss: 0.3465
# Epoch 8/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 467s 16s/step - accuracy: 0.8684 - loss: 0.3440 - val_accuracy: 0.8713 - val_loss: 0.3193
# Epoch 9/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 497s 16s/step - accuracy: 0.8808 - loss: 0.2753 - val_accuracy: 0.8830 - val_loss: 0.2788
# Epoch 10/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 456s 15s/step - accuracy: 0.9091 - loss: 0.2100 - val_accuracy: 0.9649 - val_loss: 0.0662
# Epoch 11/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 461s 15s/step - accuracy: 0.9488 - loss: 0.1701 - val_accuracy: 0.9766 - val_loss: 0.0821
# Epoch 12/50
#  4/22 ━━━━━━━━━━━━━━━━━━━━ 4:01 13s/step - accuracy: 1.0000 - loss: 0.0611

# %%
# Evaluate the model
val_loss, val_accuracy = model.evaluate(val_generator)
print(f"Validation Loss: {val_loss:.4f}")
print(f"Validation Accuracy: {val_accuracy:.4f}")

# Plot training history
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
